# %%
import numpy as np
import matplotlib.pyplot as plt

from random import shuffle
from sklearn.datasets import fetch_openml

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.utils import check_random_state
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
from sklearn.model_selection import KFold

from cross_validation import *
from utils import *

# %load_ext autoreload
# %autoreload 2

# %%
X, y = fetch_openml('mnist_784', return_X_y=True, as_frame=False)

# %%
X.shape
# Out:
# (70000, 784)

# %%
plot_samples(X[:8], y[:8])

# %%
# splitting into test and train
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=3000, test_size=800)

# %%
# normalization
X_train = normalize(X_train)
X_test = normalize(X_test)

# %%
classifiers = {
    'knn': KNeighborsClassifier(5),
    'svm': SVC(),
    'd_tree': DecisionTreeClassifier(max_depth=5),
    'log_reg': LogisticRegression()
}

# %% [markdown]
# KNN

# %%
test_classifier(classifiers['knn'], X_train, y_train, X_test, y_test)
# Out:
# [0.92, 0.935, 0.92, 0.9216666666666666, 0.91]
# Best classifier performance: 0.9213

# %% [markdown]
# SVM

# %%
test_classifier(classifiers['svm'], X_train, y_train, X_test, y_test)
# Out:
# [0.9416666666666667, 0.9483333333333334, 0.9466666666666667, 0.9416666666666667, 0.945]
# Best classifier performance: 0.9463

# %% [markdown]
# Decision Tree

# %%
test_classifier(classifiers['d_tree'], X_train, y_train, X_test, y_test)
# Out:
# [0.6383333333333333, 0.6366666666666667, 0.6433333333333333, 0.6133333333333333, 0.625]
# Best classifier performance: 0.6025

# %% [markdown]
# Logistic regression

# %%
test_classifier(classifiers['log_reg'], X_train, y_train, X_test, y_test)
# Out:
# [0.8716666666666667, 0.89, 0.8766666666666667, 0.8866666666666667, 0.8733333333333333]
# Best classifier performance: 0.8725

# %%
_, axes = plt.subplots(nrows=2, ncols=5, figsize=(10, 5))

for ax, image, label in zip(axes.reshape(-1), classifiers['log_reg'].coef_, classifiers['log_reg'].classes_):
    ax.set_axis_off()
    ax.imshow(np.abs(image.reshape((28, 28))))
    ax.set_title("class: %s" % str(label))

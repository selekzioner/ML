# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from task0 import *

# %%
dataset = datasets.load_breast_cancer()
x = dataset.data
y = dataset.target
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=10)

# %%
y_test.shape
# Out:
# (228,)

# %%
#model = KNeighborsClassifier(n_neighbors=20)
model = LogisticRegression(solver='lbfgs', max_iter=10000, random_state=0)
model.fit(X_train, y_train)
#probs = model.predict_proba(X_test)[:, 0] # probs: probs - probablitity of 0 class, y_test - gt
probs = np.random.rand(228)

# %%
drawROC(probs, y_test)
# Out:
# Area :0.4792286126922096
# skilearn area :0.4792286126922096

# %%
drawPR(probs, y_test)
# Out:
# Area :0.34752939727188326
